# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import (
    precision_recall_curve,
    roc_curve,
    roc_auc_score,
    f1_score,
    auc,
)


sns.set(style="whitegrid")
sns.set_color_codes("pastel")

# %%
full_train = pd.read_csv("datasets/train_clean.csv")

to_drop = [
    "Name",
    "Ticket",
    "Embarked",
    "PassengerId",
    *[c for c in full_train if "cabin" in c.lower()],
]

full_train.drop(columns=to_drop, inplace=True)

target_col = "Survived"

X = full_train.drop(target_col, axis=1)
y = full_train[target_col]

X_train, y_train = X, y

model = MultinomialNB()

param_grid = {
    "alpha": [0.1, 0.5, 1.0, 5.0, 10.0],
    "fit_prior": [True, False],
}

grid_search = GridSearchCV(
    model, param_grid, n_jobs=1, cv=5, scoring="accuracy", verbose=4
)

grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print(f"Best Parameters: {best_params}")
print(f"Best Score: {grid_search.best_score_:.4f}")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .........alpha=0.1, fit_prior=True;, score=0.792 total time=   0.0s
# [CV 2/5] END .........alpha=0.1, fit_prior=True;, score=0.798 total time=   0.0s
# [CV 3/5] END .........alpha=0.1, fit_prior=True;, score=0.775 total time=   0.0s
# [CV 4/5] END .........alpha=0.1, fit_prior=True;, score=0.753 total time=   0.0s
# [CV 5/5] END .........alpha=0.1, fit_prior=True;, score=0.768 total time=   0.0s
# [CV 1/5] END ........alpha=0.1, fit_prior=False;, score=0.764 total time=   0.0s
# [CV 2/5] END ........alpha=0.1, fit_prior=False;, score=0.798 total time=   0.0s
# [CV 3/5] END ........alpha=0.1, fit_prior=False;, score=0.775 total time=   0.0s
# [CV 4/5] END ........alpha=0.1, fit_prior=False;, score=0.753 total time=   0.0s
# [CV 5/5] END ........alpha=0.1, fit_prior=False;, score=0.774 total time=   0.0s
# [CV 1/5] END .........alpha=0.5, fit_prior=True;, score=0.792 total time=   0.0s
# [CV 2/5] END .........alpha=0.5, fit_prior=True;, score=0.798 total time=   0.0s
# [CV 3/5] END .........alpha=0.5, fit_prior=True;, score=0.775 total time=   0.0s
# [CV 4/5] END .........alpha=0.5, fit_prior=True;, score=0.753 total time=   0.0s
# [CV 5/5] END .........alpha=0.5, fit_prior=True;, score=0.768 total time=   0.0s
# [CV 1/5] END ........alpha=0.5, fit_prior=False;, score=0.764 total time=   0.0s
# [CV 2/5] END ........alpha=0.5, fit_prior=False;, score=0.798 total time=   0.0s
# [CV 3/5] END ........alpha=0.5, fit_prior=False;, score=0.775 total time=   0.0s
# [CV 4/5] END ........alpha=0.5, fit_prior=False;, score=0.753 total time=   0.0s
# [CV 5/5] END ........alpha=0.5, fit_prior=False;, score=0.774 total time=   0.0s
# [CV 1/5] END .........alpha=1.0, fit_prior=True;, score=0.792 total time=   0.0s
# [CV 2/5] END .........alpha=1.0, fit_prior=True;, score=0.798 total time=   0.0s
# [CV 3/5] END .........alpha=1.0, fit_prior=True;, score=0.775 total time=   0.0s
# [CV 4/5] END .........alpha=1.0, fit_prior=True;, score=0.758 total time=   0.0s
# [CV 5/5] END .........alpha=1.0, fit_prior=True;, score=0.768 total time=   0.0s
# [CV 1/5] END ........alpha=1.0, fit_prior=False;, score=0.764 total time=   0.0s
# [CV 2/5] END ........alpha=1.0, fit_prior=False;, score=0.798 total time=   0.0s
# [CV 3/5] END ........alpha=1.0, fit_prior=False;, score=0.775 total time=   0.0s
# [CV 4/5] END ........alpha=1.0, fit_prior=False;, score=0.753 total time=   0.0s
# [CV 5/5] END ........alpha=1.0, fit_prior=False;, score=0.780 total time=   0.0s
# [CV 1/5] END .........alpha=5.0, fit_prior=True;, score=0.792 total time=   0.0s
# [CV 2/5] END .........alpha=5.0, fit_prior=True;, score=0.798 total time=   0.0s
# [CV 3/5] END .........alpha=5.0, fit_prior=True;, score=0.775 total time=   0.0s
# [CV 4/5] END .........alpha=5.0, fit_prior=True;, score=0.758 total time=   0.0s
# [CV 5/5] END .........alpha=5.0, fit_prior=True;, score=0.774 total time=   0.0s
# [CV 1/5] END ........alpha=5.0, fit_prior=False;, score=0.775 total time=   0.0s
# [CV 2/5] END ........alpha=5.0, fit_prior=False;, score=0.798 total time=   0.0s
# [CV 3/5] END ........alpha=5.0, fit_prior=False;, score=0.775 total time=   0.0s
# [CV 4/5] END ........alpha=5.0, fit_prior=False;, score=0.770 total time=   0.0s
# [CV 5/5] END ........alpha=5.0, fit_prior=False;, score=0.780 total time=   0.0s
# [CV 1/5] END ........alpha=10.0, fit_prior=True;, score=0.792 total time=   0.0s
# [CV 2/5] END ........alpha=10.0, fit_prior=True;, score=0.798 total time=   0.0s
# [CV 3/5] END ........alpha=10.0, fit_prior=True;, score=0.775 total time=   0.0s
# [CV 4/5] END ........alpha=10.0, fit_prior=True;, score=0.753 total time=   0.0s
# [CV 5/5] END ........alpha=10.0, fit_prior=True;, score=0.774 total time=   0.0s
# [CV 1/5] END .......alpha=10.0, fit_prior=False;, score=0.775 total time=   0.0s
# [CV 2/5] END .......alpha=10.0, fit_prior=False;, score=0.798 total time=   0.0s
# [CV 3/5] END .......alpha=10.0, fit_prior=False;, score=0.775 total time=   0.0s
# [CV 4/5] END .......alpha=10.0, fit_prior=False;, score=0.770 total time=   0.0s
# [CV 5/5] END .......alpha=10.0, fit_prior=False;, score=0.780 total time=   0.0s
# Best Parameters: {'alpha': 5.0, 'fit_prior': False}
# Best Score: 0.7795

# %%
import joblib

joblib.dump(
    grid_search,
    f"../models/{grid_search.best_estimator_.__class__.__name__}_{grid_search.best_score_ * 100:.4f}.joblib",
)
# Out:
# ['models/MultinomialNB_77.9528.joblib']

# %%
model_name = grid_search.estimator.__class__.__name__

get_best = True  # get the best model or the latest model

# get files in models sorted by last modified
if get_best:
    import os
    import re

    files = os.listdir("../models")
    files = [f for f in files if re.match(f"{model_name}_.*\.joblib", f)]
    files = sorted(
        files, key=lambda x: re.search(r"_(\d+\.\d+)\.joblib", x).group(1), reverse=True
    )
    file_name = files[0]
else:
    import os
    import re

    files = os.listdir("../models")
    files = [f for f in files if re.match(f"{model_name}_.*\.joblib", f)]
    files = sorted(
        files, key=lambda x: os.path.getmtime(os.path.join("models", x)), reverse=True
    )
    file_name = files[0]
loaded_grid_search = joblib.load(f"../models/{file_name}")

# %%
for k, v in loaded_grid_search.cv_results_.items():
    print(k, v, sep="\t")
# Out:
# mean_fit_time	[0.00189414 0.00162406 0.00154486 0.00152788 0.00151114 0.00148454
#  0.0015048  0.00148978 0.00156918 0.00151935]
# std_fit_time	[3.77632258e-04 1.04706470e-04 1.11234734e-04 9.88943023e-05
#  5.90439941e-05 4.54059655e-05 7.67166527e-05 6.84008901e-05
#  2.09396055e-04 6.36511703e-05]
# mean_score_time	[0.00115786 0.00113478 0.00105357 0.00100741 0.00099163 0.00097723
#  0.00097227 0.00097737 0.00097399 0.0010056 ]
# std_score_time	[1.77728256e-04 1.56446311e-04 1.06137461e-04 6.80788545e-05
#  9.25653801e-06 3.17715994e-05 2.78458203e-05 2.86977542e-05
#  5.85099595e-05 7.28830271e-05]
# param_alpha	[0.1 0.1 0.5 0.5 1.0 1.0 5.0 5.0 10.0 10.0]
# param_fit_prior	[True False True False True False True False True False]
# params	[{'alpha': 0.1, 'fit_prior': True}, {'alpha': 0.1, 'fit_prior': False}, {'alpha': 0.5, 'fit_prior': True}, {'alpha': 0.5, 'fit_prior': False}, {'alpha': 1.0, 'fit_prior': True}, {'alpha': 1.0, 'fit_prior': False}, {'alpha': 5.0, 'fit_prior': True}, {'alpha': 5.0, 'fit_prior': False}, {'alpha': 10.0, 'fit_prior': True}, {'alpha': 10.0, 'fit_prior': False}]
# split0_test_score	[0.79213483 0.76404494 0.79213483 0.76404494 0.79213483 0.76404494
#  0.79213483 0.7752809  0.79213483 0.7752809 ]
# split1_test_score	[0.79775281 0.79775281 0.79775281 0.79775281 0.79775281 0.79775281
#  0.79775281 0.79775281 0.79775281 0.79775281]
# split2_test_score	[0.7752809 0.7752809 0.7752809 0.7752809 0.7752809 0.7752809 0.7752809
#  0.7752809 0.7752809 0.7752809]
# split3_test_score	[0.75280899 0.75280899 0.75280899 0.75280899 0.75842697 0.75280899
#  0.75842697 0.76966292 0.75280899 0.76966292]
# split4_test_score	[0.76836158 0.7740113  0.76836158 0.7740113  0.76836158 0.77966102
#  0.7740113  0.77966102 0.7740113  0.77966102]
# mean_test_score	[0.77726782 0.77277979 0.77726782 0.77277979 0.77839142 0.77390973
#  0.77952136 0.77952771 0.77839777 0.77952771]
# std_test_score	[0.0162614  0.01487652 0.0162614  0.01487652 0.01464648 0.01513939
#  0.01403425 0.00964942 0.01579282 0.00964942]
# rank_test_score	[6 9 6 9 5 8 3 1 4 1]

# %%
real_test = pd.read_csv("datasets/test_clean.csv")

# %%
real_test.drop(columns=list(set(to_drop) - {"PassengerId"}), inplace=True)

# %%
pred = pd.DataFrame(best_model.predict(real_test.drop(columns=["PassengerId"]))).rename(
    columns={0: "Survived"}
)

# %%
# get probabilities
probs = best_model.predict_proba(X_train)

# keep probabilities for the positive outcome only
probs = probs[:, 1]

# predict class values
yhat = best_model.predict(X_train)

# calculate roc-auc score
lr_auc = roc_auc_score(y_train, probs)

# calculate roc curve
ns_fpr, ns_tpr, _ = roc_curve(y_train, probs)

# get f1 score
lr_f1 = f1_score(y_train, best_model.predict(X_train))

# get auc score
lr_auc = auc(ns_fpr, ns_tpr)

# get precision & recall
lr_precision, lr_recall, _ = precision_recall_curve(y_train, probs)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get no-skill line
no_skill = len(y_train[y_train == 1]) / len(y_train)

# Set the style
sns.set(style="whitegrid")

# Plot the precision-recall curves
plt.figure(figsize=(8, 6))
sns.lineplot(x=[0, 1], y=[no_skill, no_skill], linestyle="dotted", label="No Skill")
sns.lineplot(x=lr_recall, y=lr_precision, marker=".", label=model_name)

# Set axis labels
plt.xlabel("Recall")
plt.ylabel("Precision")

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
# Plot the ROC curve
plt.figure(figsize=(8, 6))
sns.lineplot(x=ns_fpr, y=ns_tpr, linestyle="--", label=model_name)

# Set axis labels
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
pd.concat([real_test[["PassengerId"]], pred], axis=1).to_csv(
    f"../outs/{best_model.__class__.__name__}_{grid_search.best_score_ * 100:.4f}.csv",
    index=False,
)
